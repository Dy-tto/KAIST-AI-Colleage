# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
with open('/content/gdrive/My Drive/test.txt', 'w') as f :
    f.write('test line')

# %%
# !cat /content/gdrive/MyDrive/test.txt
# Out:
# test line

# %%
# !cat '/content/gdrive/My Drive/test.txt'
# Out:
# test line

# %%
# !ls -ltr
# Out:
# ls: 여름학기: No such file or directory
# total 33
# drwx------ 2 root root 4096 May 20  2020  backup
# drwx------ 2 root root 4096 May 20  2020  수업자료
# drwx------ 2 root root 4096 Sep  2  2020 'Colab Notebooks'
# drwx------ 2 root root 4096 Jun 21  2021  개인공부
# drwx------ 2 root root 4096 Jun 21  2021 '연구 프로젝트 관련'
# lrw------- 1 root root    0 Jun 24  2021  여름학기 -> /content/gdrive/.shortcut-targets-by-id/1Z5GzrdccDr-RB-K2Ah8TmMrArDjO4fo5/가을학기
# drwx------ 2 root root 4096 Aug  2 09:59  기타
# drwx------ 3 root root 4096 Aug  4 09:14  개발강의자료
# -rw------- 1 root root  151 Dec 13 21:57 '제목 없는 문서.gdoc'
# drwx------ 2 root root 4096 Dec 21 12:15  취업
# -rw------- 1 root root    9 Jan 19 01:39  test.txt

# %%
cd ..
# Out:
# /content/gdrive

# %%
# !ls -ltr
# Out:
# ls: 여름학기: No such file or directory
# total 33
# drwx------ 2 root root 4096 May 20  2020  backup
# drwx------ 2 root root 4096 May 20  2020  수업자료
# drwx------ 2 root root 4096 Sep  2  2020 'Colab Notebooks'
# drwx------ 2 root root 4096 Jun 21  2021  개인공부
# drwx------ 2 root root 4096 Jun 21  2021 '연구 프로젝트 관련'
# lrw------- 1 root root    0 Jun 24  2021  여름학기 -> /content/gdrive/.shortcut-targets-by-id/1Z5GzrdccDr-RB-K2Ah8TmMrArDjO4fo5/가을학기
# drwx------ 2 root root 4096 Aug  2 09:59  기타
# drwx------ 2 root root 4096 Aug  4 09:14  개발강의자료
# -rw------- 1 root root  151 Dec 13 21:57 '제목 없는 문서.gdoc'
# drwx------ 2 root root 4096 Dec 21 12:15  취업
# -rw------- 1 root root    9 Jan 19 01:39  test.txt

# %%
import os
os.chdir('/content/gdrive/MyDrive/ITAml')

# %%
# !ls
# Out:
# '2.data_preprocessing(오류 수정 반영).ipynb'   train_AV3.csv

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df = pd.read_csv("./winequality/winequality-data.csv")

# %%
import pandas as pd
df = pd.read_csv("./train_AV3.csv")

# %%
df.head(5)
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001002   Male      No  ...            1.0         Urban           Y
# 1  LP001003   Male     Yes  ...            1.0         Rural           N
# 2  LP001005   Male     Yes  ...            1.0         Urban           Y
# 3  LP001006   Male     Yes  ...            1.0         Urban           Y
# 4  LP001008   Male      No  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %%
from google.colab import files
uploaded_file=files.upload()
# Out:
#      <input type="file" id="files-af0fa5c3-2d2e-4af3-bc47-96d3431148f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af0fa5c3-2d2e-4af3-bc47-96d3431148f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winequality-solution-input.csv to winequality-solution-input.csv

# %%
print(uploaded_file)
# Out:
# {'winequality-solution-input.csv': b'fixed.acidity,volatile.acidity,citric.acid,residual.sugar,chlorides,free.sulfur.dioxide,total.sulfur.dioxide,density,pH,sulphates,alcohol,id\n6.7,0.29,0.45,14.3,0.054,30,181,0.99869,3.14,0.57,9.1,1\n7.4,0.32,0.55,16.6,0.056,53,238,1.0017,2.96,0.58,8.7,2\n7.6,0.38,0.2,3.4,0.046,9,116,0.9944,3.15,0.41,9.4,3\n7.9,0.14,0.45,1.8,0.05,17,114,0.9948,3.33,0.49,10.7,4\n7.9,0.16,0.3,7.4,0.05,58,152,0.99612,3.12,0.37,9.5,5\n5.8,0.31,0.32,4.5,0.024,28,94,0.98906,3.25,0.52,13.7,6\n7.8,0.28,0.34,1.6,0.028,32,118,0.9901,3,0.38,12.1,7\n7,0.23,0.35,1.4,0.036,31,113,0.9912,3.16,0.48,10.8,8\n6.8,0.35,0.44,6.5,0.056,31,161,0.9952,3.14,0.44,9.5,9\n6.4,0.22,0.34,1.4,0.023,56,115,0.98958,3.18,0.7,11.7,10\n6.2,0.46,0.25,4.4,0.066,62,207,0.9939,3.25,0.52,9.8,11\n7.8,0.3,0.74,1.8,0.033,33,156,0.991,3.29,0.52,12.8,12\n6.2,0.23,0.36,17.2,0.039,37,130,0.99946,3.23,0.43,8.8,13\n6.5,0.18,0.41,14.2,0.039,47,129,0.99678,3.28,0.72,10.3,14\n7.7,0.3,0.42,14.3,0.045,45,213,0.9991,3.1
# ...
