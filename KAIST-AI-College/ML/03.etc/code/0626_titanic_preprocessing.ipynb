# %% [markdown]
# # 1. 데이터 로딩

# %% [markdown]
# # 2. Null 값 확인

# %% [markdown]
# # 3. 각 컬럼과 y 값 과의 관계 - 그래프로 확인

# %% [markdown]
# # 4. NULL 처리

# %% [markdown]
# # 5. X,y 나누고 필요 없는 컬럼 제거,

# %% [markdown]
# # 6.라벨인코딩
